# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # 1. Scraping car details form the website Olx

# %% [markdown]
# # 1.1 connecting to web driver

# %%
driver=webdriver.Chrome(r"c://chromedriver.exe")

# %% [markdown]
# # 1.2 connecting to website

# %%
driver.get("https://www.olx.in/cars_c84")

# %%
#click on Load more button 
#to increase the data counts
start=0
end=13
for page in range(start,end):#for loop for scrapping 13 page
    load_button=driver.find_element_by_xpath("//button[@data-aut-id='btnLoadMore']")
    load_button.click()
    time.sleep(10)

# %% [markdown]
# # 1.3 Extracting required fields

# %%
#creating empty list
brand=[]
model=[]
varient=[]
year=[]
kilometers=[]
fuel=[]
no_of_owners=[]
location=[]
price=[]
href_url_1=[]
#extracting price
try:
    for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']/li/a/div/span[1]"):
        price.append(int(i.text.replace("₹","").replace(",","").replace(" ",""))) #appending the price from price tag
except:
    price.append("")
#extracting location tag
try:
    for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']/li/a/div/div/span[1]"):
        loc_split=i.text.split()
        location.append(loc_split[-1])#appending the location from location tag
except:
    location.append("")
#Extracting all href link
url=driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']/li/a")
for i in url:
    href_url_1.append(i.get_attribute("href"))
for url in href_url_1:
    driver.get(url)
    #for scraping brand
    try:
        brand_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        brand_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        brand_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        brand_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        brand_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        brand_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        brand_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        brand_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (brand_1.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_2.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_3.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_4.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_5.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_6.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_7.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        elif (brand_8.text=="Brand"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                brand.append(o.text) #appending the brand in brand tag
        else:
            brand.append(" ") 
    except NoSuchElementException:#handling no such element exception
        brand.append('')
    except StaleElementReferenceException:#handling Stale element exception
        brand.append('')    
    #for scraping model
    try:
        model_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        model_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        model_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        model_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        model_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        model_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        model_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        model_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (model_1.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_2.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_3.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_4.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_5.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_6.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_7.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        elif (model_8.text=="Model"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                model.append(o.text) #appending the model in model tag
        else:
            model.append(" ") 
    except NoSuchElementException:#handling no such element exception
        model.append('')
    except StaleElementReferenceException:#handling Stale element exception
        model.append('')     
    #for scraping fuel
    try:
        fuel_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        fuel_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        fuel_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        fuel_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        fuel_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        fuel_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        fuel_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        fuel_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (fuel_1.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_2.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_3.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_4.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_5.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_6.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_7.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        elif (fuel_8.text=="Fuel"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                fuel.append(o.text) #appending the fuel in fuel tag
        else:
            fuel.append(" ") 
    except NoSuchElementException:#handling no such element exception
        fuel.append('')
    except StaleElementReferenceException:#handling Stale element exception
        fuel.append('')    
    #for scraping year
    try:
        year_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        year_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        year_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        year_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        year_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        year_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        year_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        year_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (year_1.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_2.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_3.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_4.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_5.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_6.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_7.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        elif (year_8.text=="Year"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                year.append(o.text) #appending the year in year tag
        else:
            year.append(" ") 
    except NoSuchElementException:#handling no such element exception
        year.append('')
    except StaleElementReferenceException:#handling Stale element exception
        year.append('')    
    #for scraping kilometers
    try:
        kilometers_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        kilometers_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        kilometers_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        kilometers_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        kilometers_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        kilometers_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        kilometers_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        kilometers_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (kilometers_1.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_2.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_3.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_4.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_5.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_6.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_7.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                kilometers.append(o.text.replace(" km","").replace(",","")) #appending the kilometers in kilometers tag
        elif (kilometers_8.text=="KM driven"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                kilometers.append(o.text) #appending the kilometers in kilometers tag
        else:
            kilometers.append(" ") 
    except NoSuchElementException:#handling no such element exception
        kilometers.append('')
    except StaleElementReferenceException:#handling Stale element exception
        kilometers.append('')    
    #for scraping no_of_owners
    try:
        no_of_owners_1=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[1]")
        no_of_owners_2=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[1]")
        no_of_owners_3=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[1]")
        no_of_owners_4=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[1]")
        no_of_owners_5=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[1]")
        no_of_owners_6=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[1]")
        no_of_owners_7=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[1]")
        no_of_owners_8=driver.find_element_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[1]")
        if (no_of_owners_1.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_2.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_3.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_4.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_5.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_6.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[6]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_7.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        elif (no_of_owners_8.text=="No. of Owners"):
            for o in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]"):
                no_of_owners.append(o.text) #appending the no_of_owners in no_of_owners tag
        else:
            no_of_owners.append(" ") 
    except NoSuchElementException:#handling no such element exception
        no_of_owners.append('')
    except StaleElementReferenceException:#handling Stale element exception
        no_of_owners.append('')

# %%
print(len(brand),len(model),len(year),len(kilometers),len(fuel),len(no_of_owners),len(location),len(price))
# Out:
# 500 500 500 500 500 500 500 500

# %%
print(price,brand,model,year,kilometers,fuel,no_of_owners,location)
# Out:
# [399999, 651000, 618000, 665000, 235000, 650000, 480000, 399000, 500000, 350000, 680000, 435000, 328000, 125000, 300000, 300000, 255000, 615000, 570000, 400000, 575000, 265000, 2251000, 490000, 325000, 225000, 450000, 749999, 511000, 1050000, 310000, 400000, 600000, 160000, 340000, 750000, 225000, 181000, 465000, 781000, 475000, 499000, 76000, 949000, 540000, 150000, 428000, 435000, 800000, 240000, 1775000, 624000, 425000, 270000, 595000, 295000, 115000, 350000, 275000, 275000, 187000, 275000, 1560000, 500000, 275000, 760000, 170000, 950000, 635000, 2500000, 185000, 1650000, 225000, 225000, 545000, 999999, 400000, 1849000, 325000, 530000, 2300000, 410000, 460000, 160000, 1149999, 280000, 1325000, 299999, 285000, 491000, 480000, 265000, 280000, 495000, 1835000, 283000, 60000, 420000, 1250000, 360000, 35000, 1260000, 425000, 225000, 265000, 625000, 990000, 445000, 328000, 1700000, 165000, 280000, 260000, 715000, 425000, 545000, 210000, 981000, 1875111, 1200000, 145000, 52000, 4850000, 315000, 320000, 290000, 1700000, 135000, 551000, 740000, 775000, 310000, 550000, 775000, 725000, 380000, 1350000, 490000, 175000, 554000, 825000, 1340000, 470000, 231000, 199000, 495000, 990000, 235000, 199000, 195000, 155000, 898000, 175000, 445000, 565000, 169999, 230000, 3350000, 165000, 420000, 110000, 865000, 1780000, 211000, 330000, 1000000, 1290000, 215000, 290000, 274999, 600000, 450000, 600000, 160000, 100000, 100000, 450000, 725000, 1850000, 275000, 220000, 275000, 245000, 280000, 601000, 425000, 240000, 1351000, 210000, 740000, 495000, 561000, 1190000, 455000, 770000, 275000, 
# 495       Mahindra                e2o  2008     172000         Diesel
# 496         Toyota             Innova  2008     311367         Diesel
# 497     Volkswagen              Vento  2021          1         Diesel
# 498         Nissan             Evalia  2014     100000         Diesel
# 499          Honda             Others  2016      25000         Petrol
#
#     No.of.owners     Location   Price
# 0            1st        KOCHI  399999
# 1            1st       RAJKOT  651000
# 2                       DELHI  618000
# 3            1st     BAREILLY  665000
# 4            1st        DELHI  235000
# ..           ...          ...     ...
# 495           4+  RAJAPALAYAM  325000
# 496          2nd     CHITTOOR  450000
# 497          1st    ALLAHABAD   15000
# 498          2nd      CHENNAI  400000
# 499          1st     PHAGWARA   38000
#
# [500 rows x 8 columns]

# %%
cars1.to_csv('cars1.csv')

# %% [markdown]
# # 2. Scraping car details form the website carwale

# %% [markdown]
# # 2.1 connecting to web driver

# %%
driver=webdriver.Chrome(r"c://chromedriver.exe")

# %% [markdown]
# # 2.2 connecting to website

# %%
city_list=["https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=177&pc=177&pn=1",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=176&pc=176",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=10&pc=10",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=2&pc=2&pn=2&lcr=24&ldr=0&lir=0",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=128&pc=128&pn=2&lcr=24&ldr=0&lir=0",
           "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=3001&pc=3001",
           "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=246&pc=246&pn=2&lcr=24&ldr=0&lir=0",           
           "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=3000&pc=3000",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=105&pc=105",
          "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&city=40&pc=40"]

# %%
#creating empty list
brand=[]
model=[]
varient=[]
year=[]
kilometers=[]
fuel=[]
no_of_owners=[]
location=[]
price=[]

# %%
for i in city_list:
    driver.get(i)          
    #scrolling down to make sure we get more data in single frame
    #to increase the data counts
    start=0
    end=20
    for page in range(start,end):#for loop for scrapping 15 page
        #scrolling down to make sure we get 100 images in sinle frame
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        driver.execute_script("window.scrollTo(0,-1200)")
        time.sleep(5)
    #Extracting all href link
    href_url_1=[]
    url=driver.find_elements_by_xpath("//div[@class='card-detail-block__data']/a")
    for i in url:
        href_url_1.append(i.get_attribute("href"))
    for url in href_url_1:
        driver.get(url)
        #extracting price
        try:
            for i in driver.find_elements_by_xpath("/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p"):
                price.append(i.text.replace("Lakh","").replace("₹","").replace("Crore","0").replace(" ","")) #appending the price from price tag
        except:
            price.append("")
        #extracting brand tag
        try:
            for i in driver.find_elements_by_xpath("//ul[@class='special-skin-text']/li[4]/a/span"):
                brand.append(i.text)#appending the location from location tag
        except:
            brand.append("")
        #extracting model tag
        try:
            for i in driver.find_elements_by_xpath("//ul[@class='special-skin-text']/li[5]/a/span"):
                model.append(i.text)#appending the model from model tag
        except:
            model.append("")
        #extracting year tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='overview']/div/ul/li[2]/div[2]"):
                year_text=i.text.replace(" ","")
                year_regex=re.sub("[a-zA-Z]","",year_text)
                year.append(year_regex)#appending the year from year tag
        except:
            year.append("")
        #extracting kilometers tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='overview']/div/ul/li[3]/div[2]"):
                kilometers.append(i.text.replace("km","").replace(",","").replace(" ",""))#appending the kilometers from kilometer tag
        except:
            kilometers.append("")
        #extracting fuel tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='overview']/div/ul/li[4]/div[2]"):
                fuel.append(i.text)#appending the fuel type from fuel tag
        except:
            fuel.append("")
        #extracting no_of_owners tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='overview']/div/ul/li[9]/div[2]"):
                #appending the No of owners from no of owners tag
                no_of_owners.append(i.text.replace("First", "1st").replace("Second","2nd").replace("Third","3rd").replace("Fourth","4th").replace("or More","+"))
        except:
            no_of_owners.append("")
        #extracting location tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='available-text']"):
                loc_split=i.text.split()
                location.append(loc_split[-1])#appending the location from location tag
        except:
            location.append("")
            
price2=[]
price = [float(i) for i in price]
for i in price:
    price2.append(int(i*100000))

# %%
print(len(price2),len(brand),len(model),len(year),len(kilometers),len(fuel),len(no_of_owners),len(location))
# Out:
# 428 428 428 428 428 428 428 428

# %%
print(price2,brand,model,year,kilometers,fuel,no_of_owners,location)
# Out:
# [825000, 1950000, 1390000, 630000, 525000, 2595000, 590000, 1200000, 2350000, 685000, 730000, 875000, 1650000, 434999, 1075000, 440000, 4800000, 565000, 1290000, 1075000, 3350000, 590000, 2900000, 575000, 3200000, 1050000, 1950000, 1275000, 585000, 440000, 1350000, 830000, 685000, 1350000, 830000, 190000, 590000, 1390000, 2190000, 440000, 825000, 1250000, 2300000, 850000, 1200000, 540000, 665000, 640000, 350000, 800000, 525000, 630000, 1350000, 459999, 415000, 650000, 1175000, 1250000, 1425000, 490000, 1075000, 1875000, 1025000, 690000, 775000, 1675000, 1450000, 1125000, 409999, 1270000, 1700000, 800000, 2250000, 825000, 1250000, 565000, 575000, 640000, 235000, 7900000, 235000, 4200000, 465000, 540000, 660000, 750000, 245000, 1675000, 375000, 1625000, 590000, 2390000, 730000, 725000, 695000, 760000, 509999, 500000, 300000, 975000, 390000, 585000, 500000, 595000, 1150000, 1550000, 1750000, 700000, 250000, 8500000, 235000, 1050000, 475000, 258000, 265000, 162000, 430000, 440000, 1350000, 2400000, 1975000, 1600000, 4550000, 1050000, 1125000, 1250000, 2350000, 3600000, 750000, 4200000, 275000, 525000, 650000, 1760000, 850000, 1500000, 140000, 450000, 365000, 7500000, 1525000, 4350000, 1850000,
# %%
cars2=pd.DataFrame({"Brand":brand,"Model":model,"Year":year,"Kilometers":kilometers,
               "Fuel":fuel,
               "No.of.owners":no_of_owners,
               "Location":location,
               "Price":price2})
cars2
# Out:
#              Brand       Model  Year Kilometers       Fuel No.of.owners  \
# 0            Honda        City  2016      26160     Petrol          1st
# 1            Skoda     Octavia  2017      74330     Diesel          1st
# 2             Audi          A6  2013     123456     Diesel          2nd
# 3          Hyundai   Elite i20  2015     100400     Diesel          1st
# 4          Hyundai   Elite i20  2015      79100     Petrol          1st
# ..             ...         ...   ...        ...        ...          ...
# 423         Toyota  Etios Liva  2016      34867     Petrol          1st
# 424  Maruti Suzuki       Swift  2020       1949     Petrol          1st
# 425  Maruti Suzuki     Wagon R  2014     113184  CNG + Cng          1st
# 426  Maruti Suzuki        Ritz  2011      57123     Petrol          2nd
# 427           Ford        Figo  2011      99123     Diesel          2nd
#
#        Location    Price
# 0    Coimbatore   825000
# 1    Coimbatore  1950000
# 2    Coimbatore  1390000
# 3    Coimbatore   630000
# 4    Coimbatore   525000
# ..          ...      ...
# 423       Thane   455000
# 424       Thane   595000
# 425       Thane   345000
# 426       Thane   225000
# 427       Thane   285000
#
# [428 rows x 8 columns]

# %%
cars2.to_csv('cars2.csv')

# %% [markdown]
# # 3. Scraping car details form the website cardekho

# %% [markdown]
# ## 3.1 connecting to web driver

# %%
driver=webdriver.Chrome(r"c://chromedriver.exe")

# %%
#creating empty list
brand=[]
model=[]
model1=[]
varient=[]
year=[]
kilometers=[]
fuel=[]
no_of_owners=[]
location=[]
price=[]

# %% [markdown]
# ## 3.2 connecting to website

# %%
city=["chennai","mumbai","new-delhi","bangalore","kolkata","noida","pune","gurgaon","ahmedabad"]
for j in city:
    driver.get(f"https://www.cardekho.com/used-cars+in+{j}")
    time.sleep(5)
    #click on Load more button 
    #to increase the data counts
    start=0
    end=13
    for page in range(start,end):#for loop for scrapping 15 page
        #scrolling down to make sure we get 100 images in sinle frame
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        driver.execute_script("window.scrollTo(0,-1200)")
        time.sleep(5)  
    try:
        for i in driver.find_elements_by_xpath("//div[@class='price gsc_col-xs-5 text-right']/span"):
            price.append(int(float(i.text.replace("Lakh","").replace(",","").replace(" ",""))*100000)) #appending the price from price tag
    except:
        price.append("")
    #extracting year tag
    #extracting brand tag
    #extracting model tag
    try:
        for i in driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7 carsName']/a"):
            split=i.text.split()
            year.append(split[0])#appending the year from year tag
            brand.append(split[1])#appending the brand from year tag
            model.append(split[2:])#appending the model from year tag        
    except:
        year.append("")
        brand.append("")
        model1.append("")
    #extracting kilometer tag
    try:
        for i in driver.find_elements_by_xpath("//div[@class='truncate dotlist']/span[1]"):
            kilometers.append(i.text.replace("kms","").replace(",",""))#appending the kilometer from kilometer tag
    except:
        kilometers.append("")
    #extracting fuel tag
    try:
        for i in driver.find_elements_by_xpath("//div[@class='truncate dotlist']/span[2]"):
            fuel.append(i.text)#appending the fuel from fuel tag
    except:
        fuel.append("")
    href_url_1=[]
    url=driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7 carsName']/a")
    #extracting href
    for i in url:
        href_url_1.append(i.get_attribute("href"))
    for url in href_url_1:
        driver.get(url)
        #extracting no_of_owners tag
        try:
            for i in driver.find_elements_by_xpath("//*[@id='widget-Overview']/div/div/div/div[1]/ul/li[4]/div/div"):
                no_of_owners.append(i.text.replace("First Owner","1st").replace("Second Owner","2nd").replace("Third Owner","3rd").replace("Fourth & Above Owner","4+").replace("Owner",""))#appending the location from location tag
            for i in driver.find_elements_by_xpath("//*[@id='rf01']/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]"):
                no_of_owners.append(i.text.replace("First Owner","1st").replace("Second Owner","2nd").replace("Third Owner","3rd").replace("Fourth & Above Owner","4+").replace("Owner",""))#appending the location from location tag
        except NoSuchElementException as e:
            no_of_owners.append("")
        except StaleElementReferenceException:#handling Stale element exception
            no_of_owners.append('No details available')
        #extracting location tag
        location.append(j.replace("chennai","Chennai").replace("mumbai","Mumbai").replace("new-delhi","Delhi").replace("bangalore","Bangalore")
                       .replace("kolkata","Kolkata").replace("noida","Noida").replace("pune","Pune"))
    
#concatinating list in model column into a single sentence
model2=[]
for i in model:
    string = ' '.join(i)
    model2.append(string)
no_of_owners.append("")
no_of_owners2=no_of_owners[0:-1]

# %%
print(len(price),len(brand),len(model2),len(year),len(kilometers),len(fuel),len(no_of_owners2),len(location))
# Out:
# 888 888 888 888 888 888 888 888

# %%
print(price,brand,model,year,kilometers,fuel,no_of_owners2,location)
# Out:
# [400000, 1800000, 4550000, 425000, 535000, 2400000, 210000, 1199000, 725000, 550000, 660000, 800000, 1350000, 524000, 1190000, 755000, 349000, 1385000, 795000, 2050000, 725000, 425000, 520000, 620000, 425000, 540000, 560000, 225000, 550000, 712000, 660000, 475000, 375000, 175000, 250000, 725000, 360000, 690000, 725000, 850000, 875000, 1664999, 425000, 325000, 325000, 400000, 250000, 555000, 2600000, 700000, 725000, 495000, 125000, 1850000, 125000, 140000, 750000, 890000, 270000, 1150000, 750000, 969999, 425000, 750000, 650000, 620000, 430000, 550000, 5650000, 520000, 650000, 575000, 425000, 370000, 950000, 345000, 615000, 550000, 275000, 1125000, 400000, 620000, 375000, 425000, 605000, 540000, 459999, 520000, 625000, 290000, 1450000, 4860000, 830000, 550000, 265000, 560000, 325000, 650000, 225000, 285000, 450000, 5000000, 160000, 285000, 550000, 712000, 660000, 2400000, 180000, 475000, 850000, 375000, 950000, 340000, 300000, 2500000, 175000, 500000, 340000, 844999, 250000, 430000, 3300000, 725000, 990000, 125000, 580000, 160000, 3000000, 360000, 690000, 725000, 4500000, 225000, 8500000000, 550000, 1400000, 325000, 340000, 350000, 850000, 609000, 950000, 3600000, 254999, 910000, 700000, 320000, 564000, 509999, 1300000, 250000, 1250000, 335000, 490000, 625000, 180000, 250000, 434999, 610000, 620000, 1100000, 535000, 300000, 110000,
# 0          Hyundai          i10  2012     37000   Petrol          1st
# 1         Mahindra       XUV500  2019      7900   Diesel          1st
# 2    Mercedes-Benz      E-Class  2017     12000   Diesel          1st
# 3          Hyundai        Verna  2012    129000   Diesel          2nd
# 4            Honda        Amaze  2015     43000   Petrol          1st
# ..             ...          ...   ...        ...     ...          ...
# 883         Maruti      Wagon R  2018     23197   Petrol         1st
# 884         Maruti      Wagon R  2016     81674   Petrol          1st
# 885         Maruti  Swift Dzire  2019      9718   Petrol          1st
# 886          Honda         City  2011     38647   Petrol          1st
# 887         Maruti     Alto K10  2012     89579   Petrol          1st
#
#       Location    Price
# 0      Chennai   400000
# 1      Chennai  1800000
# 2      Chennai  4550000
# 3      Chennai   425000
# 4      Chennai   535000
# ..         ...      ...
# 883  ahmedabad   441000
# 884  ahmedabad   353000
# 885  ahmedabad   645000
# 886  ahmedabad   396000
# 887  ahmedabad   177000
#
# [888 rows x 8 columns]

# %%
cars3.to_csv('cars3.csv')

# %% [markdown]
# # 4. Scraping car details form the website cartrade

# %% [markdown]
# ## 4.1 connecting to web driver

# %%
driver=webdriver.Chrome(r"c://chromedriver.exe")

# %% [markdown]
# ## 4.2 connecting to website

# %%
city_list=["https://www.cartrade.com/buy-used-cars/chennai/c#city=176",
           "https://www.cartrade.com/buy-used-cars/new-delhi/c#city=10&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/bangalore/c#city=2&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/mumbai/c#city=3000&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/pune/c#city=12&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/hyderabad/c#city=105&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/kolkata/c#city=198&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/ahmedabad/c#city=128&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/noida/c#city=224&sc=-1&so=-1&pn=1",
          "https://www.cartrade.com/buy-used-cars/gurgaon/c#city=246&sc=-1&so=-1&pn=1"]

# %%
#creating empty list
brand=[]
model=[]
model=[]
varient=[]
year=[]
kilometers=[]
fuel=[]
no_of_owners=[]
location=[]
price=[]
href_url_1=[]

# %%
for i in city_list:
    driver.get(i)   
    time.sleep(5)
    #next button to make sure we get more data in different page
    #to increase the data counts
    start=0
    end=20
    for page in range(start,end):#for loop for scrapping 13 page
        url=driver.find_elements_by_xpath("//h2[@class='h2heading truncate']/a")
        for i in url:
            href_url_1.append(i.get_attribute("href"))
        next_button=driver.find_element_by_xpath("//li[@class='next']/a")
        next_button.click()
        time.sleep(5)

# %%
len(href_url_1)
# Out:
# 4858

# %%
for url in href_url_1:
    driver.get(url)
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[8]/div[1]/div[2]/div/div[1]/div[1]/span[2]"):
            price.append(int(float(i.text.replace("Lakh","").replace("₹","").replace("Crore","0").replace(" ",""))*100000)) #appending the price from price tag
    except:
        price.append("")
    #extracting brand tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[1]/div/ul/li[4]/a/span"):
            brand.append(i.text)#appending the brand from brand tag
    except:
        brand.append("")
    #extracting model tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[1]/div/ul/li[5]/a/span"):
            model.append(i.text)#appending the model from model tag
    except:
        model.append("")
    #extracting location tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[1]/div/ul/li[3]/a/span"):
            location.append(i.text)#appending the model from model tag
    except:
        location.append("")
    #extracting fuel tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]"):
            fuel.append(i.text)#appending the model from model tag
    except:
        fuel.append("")
    #extracting kilometers tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[3]/td[2]"):
            kilometers.append(i.text)#appending the model from model tag
    except:
        kilometers.append("")
    #extracting no_of_owners tag
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[5]/td[2]"):
            #appending the No of owners from no of owners tag
            no_of_owners.append(i.text.replace("First", "1st").replace("Second","2nd").replace("Third","3rd").replace("Fourth","4th").replace("or More","+"))
    except:
        no_of_owners.append("")
    try:
        for i in driver.find_elements_by_xpath("//*[@id='idbybody']/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[8]/td[2]"):
            #appending the No of owners from no of owners tag
            year.append(i.text)#appending the model from model tag
    except:
        year.append("")

# %%
print(len(price),len(brand),len(model),len(year),len(kilometers),len(fuel),len(no_of_owners),len(location))
# Out:
# 9606 9606 9606 9606 9606 9606 9606 9606

# %%
print(price,brand,model,year,kilometers,fuel,no_of_owners,location)
# Out:
# ['', 400000, '', 400000, 200000, 450000, 110000, 140000, '', '', 500000, '', 100000, 220000, 150000, 200000, 280000, 430000, '', 110000, 125000, 200000, 850000, 975000, 1760000, 525000, 650000, 275000, 140000, 4200000, 2100000, 700000, 1500000, 850000, 509999, 165000, 1150000, 535000, 725000, 475000, 650000, 750000, 1400000, 630000, 250000, 400000, 630000, 1400000, 250000, 360000, 400000, 3800000, 2700000, 750000, 1085000, 475000, 2450000, 3600000, 2500000, 500000, 2690000, 595000, 3250000, 850000, 1270000, 900000, 595000, 275000, 275000, 1750000, 900000, 2450000, 3600000, 1270000, 2500000, 1750000, 1150000, 865000, 650000, 1789999, 1550000, 1150000, 650000, 750000, 1795000, 650000, 675000, 875000, 675000, 1270000, 1300000, 850000, 1625000, 1700000, 1270000, 1789999, 1550000, 1150000, 1125000, 525000, 475000, 425000, 2500000, 450000, 2700000, 1500000, 3
# %%
cars4=pd.DataFrame({"Brand":brand,"Model":model,"Year":year,"Kilometers":kilometers,
               "Fuel":fuel,
               "No.of.owners":no_of_owners,
               "Location":location,
               "Price":price})
cars4
# Out:
#               Brand              Model  Year    Kilometers    Fuel  \
# 0     Maruti Suzuki                800  1998    41,500 Kms  Petrol
# 1              Ford            Model T  1998  1,00,000 Kms  Petrol
# 2     Maruti Suzuki                Zen  1998  1,20,000 Kms  Petrol
# 3          Mahindra               Thar  1998    39,000 Kms  Diesel
# 4     Maruti Suzuki                800  1998     3,000 Kms  Petrol
# ...             ...                ...   ...           ...     ...
# 9601           Audi                 Q3  2017    44,600 Kms  Petrol
# 9602           Audi                 A3  2017    34,000 Kms  Diesel
# 9603  Mercedes-Benz  E-Class Cabriolet  2016    33,100 Kms  Petrol
# 9604           Audi                 A4  2011    70,000 Kms  Petrol
# 9605  Mercedes-Benz            S-Class  2013    10,000 Kms  Petrol
#
#      No.of.owners Location    Price
# 0             2nd  Chennai
# 1             1st  Chennai   400000
# 2             2nd  Chennai
# 3             3rd  Chennai   400000
# 4             1st  Chennai   200000
# ...           ...      ...      ...
# 9601          1st  Gurgaon  2400000
# 9602          1st  Gurgaon  2200000
# 9603          2nd    Delhi  4475000
# 9604          2nd    Delhi   900000
# 9605          1st    Delhi  2850000
#
# [9606 rows x 8 columns]

# %%
cars4.to_csv('cars4.csv')

# %% [markdown]
# # Concatinating all csv file to one

# %%
usedcars1=pd.read_csv("cars1.csv")
usedcars2=pd.read_csv("cars2.csv")
usedcars3=pd.read_csv("cars3.csv")
usedcars4=pd.read_csv("cars4.csv")

# %%
usedcars4["Kilometers"] = usedcars4['Kilometers'].str.replace("Kms","").str.replace(",","")

# %%
usedcars4
# Out:
#       Unnamed: 0          Brand              Model  Year Kilometers    Fuel  \
# 0              0  Maruti Suzuki                800  1998     41500   Petrol
# 1              1           Ford            Model T  1998    100000   Petrol
# 2              2  Maruti Suzuki                Zen  1998    120000   Petrol
# 3              3       Mahindra               Thar  1998     39000   Diesel
# 4              4  Maruti Suzuki                800  1998      3000   Petrol
# ...          ...            ...                ...   ...        ...     ...
# 9601        9601           Audi                 Q3  2017     44600   Petrol
# 9602        9602           Audi                 A3  2017     34000   Diesel
# 9603        9603  Mercedes-Benz  E-Class Cabriolet  2016     33100   Petrol
# 9604        9604           Audi                 A4  2011     70000   Petrol
# 9605        9605  Mercedes-Benz            S-Class  2013     10000   Petrol
#
#      No.of.owners Location      Price
# 0             2nd  Chennai        NaN
# 1             1st  Chennai   400000.0
# 2             2nd  Chennai        NaN
# 3             3rd  Chennai   400000.0
# 4             1st  Chennai   200000.0
# ...           ...      ...        ...
# 9601          1st  Gurgaon  2400000.0
# 9602          1st  Gurgaon  2200000.0
# 9603          2nd    Delhi  4475000.0
# 9604          2nd    Delhi   900000.0
# 9605          1st    Delhi  2850000.0
#
# [9606 rows x 9 columns]

# %%
usedcars_webscraping=pd.concat((usedcars1,usedcars2,usedcars3,usedcars4),ignore_index=True)
usedcars_webscraping
# Out:
#        Unnamed: 0          Brand              Model    Year Kilometers  \
# 0               0         Nissan              Sunny  2017.0    86000.0
# 1               1  Maruti Suzuki             Baleno  2018.0    51300.0
# 2               2            NaN                NaN     NaN        NaN
# 3               3       Mahindra  Bolero Power Plus  2019.0    28400.0
# 4               4          Honda               Brio  2011.0    48000.0
# ...           ...            ...                ...     ...        ...
# 11417        9601           Audi                 Q3  2017.0     44600
# 11418        9602           Audi                 A3  2017.0     34000
# 11419        9603  Mercedes-Benz  E-Class Cabriolet  2016.0     33100
# 11420        9604           Audi                 A4  2011.0     70000
# 11421        9605  Mercedes-Benz            S-Class  2013.0     10000
#
#                 Fuel No.of.owners  Location      Price
# 0             Diesel          1st     KOCHI   399999.0
# 1      CNG & Hybrids          1st    RAJKOT   651000.0
# 2                NaN          NaN     DELHI   618000.0
# 3             Diesel          1st  BAREILLY   665000.0
# 4             Petrol          1st     DELHI   235000.0
# ...              ...          ...       ...        ...
# 11417         Petrol          1st   Gurgaon  2400000.0
# 11418         Diesel          1st   Gurgaon  2200000.0
# 11419         Petrol          2nd     Delhi  4475000.0
# 11420         Petrol          2nd     Delhi   900000.0
# 11421         Petrol          1st     Delhi  2850000.0
#
# [11422 rows x 9 columns]

# %% [markdown]
# # saving the dataframe to excel file

# %%
df = pd.DataFrame(usedcars_webscraping)
df.to_excel('usedcars_webscraping.xlsx', index=False)
df
# Out:
#        Unnamed: 0          Brand              Model    Year Kilometers  \
# 0               0         Nissan              Sunny  2017.0    86000.0
# 1               1  Maruti Suzuki             Baleno  2018.0    51300.0
# 2               2            NaN                NaN     NaN        NaN
# 3               3       Mahindra  Bolero Power Plus  2019.0    28400.0
# 4               4          Honda               Brio  2011.0    48000.0
# ...           ...            ...                ...     ...        ...
# 11417        9601           Audi                 Q3  2017.0     44600
# 11418        9602           Audi                 A3  2017.0     34000
# 11419        9603  Mercedes-Benz  E-Class Cabriolet  2016.0     33100
# 11420        9604           Audi                 A4  2011.0     70000
# 11421        9605  Mercedes-Benz            S-Class  2013.0     10000
#
#                 Fuel No.of.owners  Location      Price
# 0             Diesel          1st     KOCHI   399999.0
# 1      CNG & Hybrids          1st    RAJKOT   651000.0
# 2                NaN          NaN     DELHI   618000.0
# 3             Diesel          1st  BAREILLY   665000.0
# 4             Petrol          1st     DELHI   235000.0
# ...              ...          ...       ...        ...
# 11417         Petrol          1st   Gurgaon  2400000.0
# 11418         Diesel          1st   Gurgaon  2200000.0
# 11419         Petrol          2nd     Delhi  4475000.0
# 11420         Petrol          2nd     Delhi   900000.0
# 11421         Petrol          1st     Delhi  2850000.0
#
# [11422 rows x 9 columns]
